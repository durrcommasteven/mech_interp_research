# %%
from analysis_tools import * 
import numpy as np 
import matplotlib.pyplot as plt

# %%
data_0 = {
    "hi": np.random.randn(1, 2)*.1 + np.array([-1, 0])[None, :],
    "how": np.random.randn(100, 2)*.1 + np.array([1, 0])[None, :],
    "are": np.random.randn(50, 2)*.1 + np.array([0, 1])[None, :],
    "you": np.random.randn(30, 2)*.1 + np.array([0, -1])[None, :],
}

data_1 = {
    "how": np.random.randn(100, 2)*.1 + np.array([1, 0])[None, :]+np.array([1, 0])[None, :],
    "are": np.random.randn(50, 2)*.1 + np.array([0, 1])[None, :]+np.array([1, 0])[None, :],
    "you": np.random.randn(30, 2)*.1 + np.array([0, -1])[None, :]+np.array([1, 0])[None, :],
    "sir": np.random.randn(1, 2)*.1 + np.array([1, 1])[None, :]+np.array([1, 0])[None, :]
}

# %%
perform_token_normalized_lda(data_0, data_1, visualize=True)
# Out:
# (array([-0.99216817,  0.12490925]),
#  array([0.54869089, 0.34413997, 0.47182262, 0.64408951, 0.28385837,
#         0.56690985, 0.44114892, 0.59932096, 0.47644132, 0.3714197 ,
#         0.46298885, 0.50870769, 0.53296044, 0.65374712, 0.55737892,
#         0.4274874 , 0.58622953, 0.33390799, 0.51769638, 0.63211335,
#         0.51261842, 0.3181146 , 0.56972498, 0.42228971, 0.5660005 ,
#         0.476442  , 0.70136991, 0.64531507, 0.58522186, 0.51346914,
#         0.604001  , 0.44589053, 0.52619977, 0.58545485, 0.33093869,
#         0.38915717, 0.45576631, 0.52656629, 0.66670644, 0.55065625,
#         0.60507811, 0.51861492, 0.54661836, 0.45577083, 0.66958523,
#         0.44998747, 0.55266183, 0.46034681, 0.44174413, 0.54071483,
#         0.3468354 , 0.36528514, 0.40736575, 0.6467456 , 0.48477222,
#         0.56371064, 0.53047353, 0.51703783, 0.52306812, 0.59744424,
#         0.49472043, 0.5110989 , 0.4368474 , 0.48701141, 0.62111833,
# ...
